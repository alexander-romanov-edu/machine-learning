# %%
import sklearn as sk
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import torch
from ucimlrepo import fetch_ucirepo
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets, linear_model, metrics, preprocessing, model_selection, svm
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from scipy.spatial import distance
from tqdm.notebook import tqdm

# %%
# %matplotlib widget

# %%
spambase = fetch_ucirepo(id=94)

spam = pd.DataFrame(spambase['data']['features'])
spam['target'] = spambase['data']['targets']

spam.sample(5, random_state=0)
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 991              0.1               0.20           1.01           0.0
# 2565             0.0               0.00           0.00           0.0
# 1906             0.0               0.00           0.00           0.0
# 1471             0.0               0.82           0.32           0.0
# 1813             0.0               0.00           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 991            0.80            0.80               0.5                0.00
# 2565           0.00            0.00               0.0                0.00
# 1906           0.00            0.00               0.0                0.00
# 1471           1.14            0.32               0.0                0.16
# 1813           0.00            0.00               0.0                0.00
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# ...

# %%
print(f"Dataset: {spambase.metadata.name}")
print(f"Задача: {spambase.metadata.abstract}")
print(f"Количество признаков: {spambase.metadata.num_features}")
print(f"Количество объектов выборки: {spambase.metadata.num_instances}")
# Out:
# Dataset: Spambase
# Задача: Classifying Email as Spam or Non-Spam
# Количество признаков: 57
# Количество объектов выборки: 4601

# %% [markdown]
# # data visualization

# %% [markdown]
# The last 3 traits are of the most interst to us as they differ strongly from the rest. Let us also pick first 2 features and check for explicit dependencies

# %%
def visualize_data(dataset):
    features = list(dataset.columns)[:2] + list(dataset.columns)[-4:]
    sns.pairplot(dataset[features], hue='target', height=2)
    plt.tight_layout()
    plt.show()
visualize_data(spam)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# As we can see both classes look very similar but we already can derive some trends:
#  - Non-spam letters contain shorter average sequences of words starting with capital letters
#  - Non-spam letters contain shorter longest sequences of consequent capital letters

# %% [markdown]
# # Feature normalization

# %%
features = list(spam.columns)[:-1]
scaler = preprocessing.StandardScaler().fit(spam[features])
spam[features] = scaler.transform(spam[features])

# %%
visualize_data(spam)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xs = spam.iloc[:, spam.columns != 'target'].values
ys = spam.iloc[:, spam.columns == 'target'].values.reshape(-1)
ys = np.array(ys)
x_train, x_test, y_train, y_test = model_selection.train_test_split(xs, ys, test_size=0.05, random_state=0)

# %% [markdown]
# # K-Neigbors

# %%
n_neighbors = 10
def get_k_neighbors_models(n, xs, ys):
    models = []
    for n_neighbors in range(1, n):
        model = KNeighborsClassifier(n_neighbors=n_neighbors)
        model.fit(xs, ys)
        models.append(model)
models = get_k_neighbors_models(n_neighbors, x_train, y_train)

# %% [markdown]
# # Perceptron

# %%
# yoinked from https://github.com/andriygav/MachineLearningSeminars/blob/master/sem6/main.ipynb
class Perceptron(torch.nn.Module):
    def __init__(self, input_dim=784, num_layers=0, 
                 hidden_dim=64, output_dim=10, p=0.0, device='cpu'):
        super(Perceptron, self).__init__()
        
        self.layers = torch.nn.Sequential()
        
        prev_size = input_dim
        for i in range(num_layers):
            self.layers.add_module('layer{}'.format(i), 
                                  torch.nn.Linear(prev_size, hidden_dim))
            self.layers.add_module('relu{}'.format(i), torch.nn.ReLU())
            self.layers.add_module('dropout{}'.format(i), torch.nn.Dropout(p=p))
            prev_size = hidden_dim
        
        self.layers.add_module('classifier', 
                               torch.nn.Linear(prev_size, output_dim))        
        self.to(device)
        
    def forward(self, input):
        return self.layers(input)
    
def trainer(model, dataset, loss_function, optimizer, epochs):
    for epoch in tqdm(range(epochs), leave=False):
        generator = torch.utils.data.DataLoader(dataset, batch_size=64, 
                                              shuffle=True)
        for x, y in tqdm(generator, leave=False):
            optimizer.zero_grad()
            x = x.to(device)
            y = y.to(device)

            output = model(x)
            loss = loss_function(output, y)
            loss.backward()
            optimizer.step()
            
            
def testing(model, dataset):
    generator = torch.utils.data.DataLoader(dataset, batch_size=64)

    pred = []
    real = []
    for x, y in tqdm(generator, leave=False):
        x = x.to(device)
        y = y.to(device)

        pred.extend(torch.argmax(model(x), dim=-1).cpu().numpy().tolist())
        real.extend(y.cpu().numpy().tolist())

    return np.mean(np.array(real) == np.array(pred)), \
           classification_report(real, pred)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = Perceptron(device=device)
tensor_train = dataset_train = torch.utils.data.TensorDataset(torch.Tensor(x_train), 
                                               torch.LongTensor(y_train))
tensor_test = dataset_train = torch.utils.data.TensorDataset(torch.Tensor(x_test), 
                                               torch.LongTensor(y_test))
_ = model.train()
trainer(model=model, dataset=dataset_train,loss_function=torch.nn.CrossEntropyLoss(),
    optimizer=torch.optim.Adam(model.parameters(), lr=0.001),
    epochs=1)
print(testing(model, dataset_test[1]))
# Out:
# Device: cpu
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 9
#       6 tensor_test = dataset_train = torch.utils.data.TensorDataset(torch.Tensor(x_test),
#       7                                                torch.LongTensor(y_test))
#       8 _ = model.train()
# ----> 9 trainer(model=model, dataset=dataset_train,loss_function=torch.nn.CrossEntropyLoss(),
#      10     optimizer=torch.optim.Adam(model.parameters(), lr=0.001),
#      11     epochs=1)
#      12 print(testing(model, dataset_test[1]))
#
# Cell In[23], line 33, in trainer(model, dataset, loss_function, optimizer, epochs)
#      30 x = x.to(device)
#      31 y = y.to(device)
# ---> 33 output = model(x)
#      34 loss = loss_function(output, y)
#      35 loss.backward()
#
# ...

# %% [markdown]
# # Count only words

# %%
def trim_non_words(x):
    return x.drop([i for i in range(len(words), x.shape[1])], axis = 1)
words_unscaled_train = trim_non_words(x_unscaled_train)
print(type(words_unscaled_train))
print(words_unscaled_train)
words_unscaled_test = trim_non_words(x_unscaled_test)

# %%
def print_vif(x):
  print(pd.Series([vif(x.values, i) for i in range(x.shape[1])], index = x.columns))
print_vif(words_unscaled_train)

# %%
scaler = preprocessing.StandardScaler().fit(words_unscaled_train)
words_train_all = words_unscaled_train
words_test_all = words_unscaled_test
words_all = spam
scaler.transform(words_train_all)
scaler.transform(words_test_all)
scaler.transform(words_all)

# %% [markdown]
# ### Some words have vif > 5. Let's try and normalize them

# %%
print(f"words \"{words[31]}\" and \"{words[33]}\" corelate")
def print_heatmap(df):
  plt.figure()
  _ = sns.heatmap(df.corr(), annot=True, fmt='.2f')

print(words_unscaled_train.shape)
drops = [words[i] for i in range(30)] + [words[i] for i in range(36, words_unscaled_train.shape[1])]
words_heatmap_train = words_unscaled_train.drop(drops, axis=1)
print(drops)
words_heatmap_train = words_heatmap_train.rename(columns = dict(list(enumerate(words))[30:35]))
print_heatmap(words_heatmap_train.join(y_train[30:35]))

# %%
print(f"Words \"857\" and \"415\" correlate strongly. Lets drop words \"telnet\", \"technology\" and \"415\"")
to_drop = ["telnet", "technology", "415"]
words_train = words_unscaled_train.drop(to_drop, axis=1)
words_test = words_unscaled_test.drop(to_drop, axis=1)
all_words_nodrop = trim_non_words(spam)
all_words = all_words_nodrop.drop(to_drop, axis=1)
words_heatmap_train = words_train.drop(drops, axis=1)

print_heatmap(words_train.join(y_train))

# %% [markdown]
# Now all words have low VIF and we can process them with no problems
